# %% [markdown]
# # Deep Research Agentic Workflow

# %% [markdown]
# Here's how our deep research workflow operates:
#
# ```mermaid
# flowchart TD
#     Start([👤 User Query])
#     Guardrail([🛡️ Input Guardrail])
#     ValidCheck{Valid Input?}
#     Error([❌ Validation Error])
#     Splitter([✂️ Topic Splitter Agent])
#     Research1([🔍 Research Agent<br/>Subtopic 1])
#     Research2([🔍 Research Agent<br/>Subtopic 2])
#     Research3([🔍 Research Agent<br/>Subtopic 3])
#     Consolidate([📋 Consolidate Findings])
#     Optimizer([⚙️ Optimizer Agent])
#     OptCheck{Needs More<br/>Research?}
#     SynthCheck{Handed Off to<br/>Synthesizer?}
#     Synthesizer([📝 Synthesizer Agent])
#     Final([📤 Final Report])
#
#     Start --> Guardrail
#     Guardrail --> ValidCheck
#     ValidCheck -->|No| Error
#     ValidCheck -->|Yes| Splitter
#     Splitter --> Research1
#     Splitter --> Research2
#     Splitter --> Research3
#     Research1 --> Consolidate
#     Research2 --> Consolidate
#     Research3 --> Consolidate
#     Consolidate --> Optimizer
#     Optimizer --> OptCheck
#     OptCheck -->|Yes| Splitter
#     OptCheck -->|No| SynthCheck
#     SynthCheck -->|Yes| Final
#     SynthCheck -->|No| Synthesizer
#     Synthesizer --> Final
#
#     style Start fill:#5e81ac,stroke:#2e3440,stroke-width:2px,color:#eceff4
#     style Guardrail fill:#d08770,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style ValidCheck fill:#ebcb8b,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style Error fill:#bf616a,stroke:#2e3440,stroke-width:2px,color:#eceff4
#     style Splitter fill:#d08770,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style Research1 fill:#d08770,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style Research2 fill:#d08770,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style Research3 fill:#d08770,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style Consolidate fill:#88c0d0,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style Optimizer fill:#d08770,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style OptCheck fill:#ebcb8b,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style SynthCheck fill:#ebcb8b,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style Synthesizer fill:#d08770,stroke:#2e3440,stroke-width:2px,color:#2e3440
#     style Final fill:#a3be8c,stroke:#2e3440,stroke-width:2px,color:#2e3440
# ```
#
# This workflow demonstrates an **advanced multi-agent research system** where:
# - **Input Guardrail** validates queries before processing
# - **Topic Splitter** breaks down complex queries into subtopics
# - **Research Agents** work in parallel using `asyncio.gather`
# - **Triage Agent** routes to synthesis or quality review
# - **Optimizer Agent** evaluates if more research is needed
# - **Synthesizer Agent** creates the final comprehensive report
